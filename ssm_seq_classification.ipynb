# %% [markdown]
# # Notebook for implementation of Seq-Classification

# %%
import torch
from torch.utils.data import Dataset
import numpy as np
from torch_geometric.utils import to_undirected
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from ssm_utlis import set_seed
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from tqdm.notebook import tqdm 
#set_seed(21)
from ssm_memory import MemoryModel
# Out:
# /home/ayushman/miniconda3/envs/py310/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/ayushman/miniconda3/envs/py310/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN3c106detail14torchCheckFailEPKcS2_jRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/ayushman/miniconda3/envs/py310/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/ayushman/miniconda3/envs/py310/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN3c106detail14torchCheckFailEPKcS2_jRKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %% [markdown]
# Dataset creation,
#
# for node $u = 0$, $ x_u \in \{-1,1\}$
#
# else if  $u\neq 0$, $x_u = U[-1,1]$

# %%
class CTDGraphDataset(Dataset):
    def __init__(self, N, M, seed=42):
        """
        Args:
            N (int): number of edges per sequence
            M (int): number of sequences
        """
        self.N = N
        self.M = M
        np.random.seed(seed)

        self.data = []
        self.labels = []

        for _ in range(M):
            # node 0 signal = label
            y = np.random.choice([0, 1])
            self.labels.append(y)

            # node signals
            signals = {0: float(y)*2-1}
            for i in range(1, N + 1):
                signals[i] = np.random.uniform(-1, 1)

            # edges
            src = np.arange(0, N)
            dst = np.arange(1, N + 1)
            times = np.sort(np.random.uniform(0, 10, N))  # increasing times

            # endpoint signals
            x_src = np.array([signals[s] for s in src])
            x_dst = np.array([signals[d] for d in dst])

            self.data.append((src, dst, times, x_src, x_dst))

    def __len__(self):
        return self.M

    def __getitem__(self, idx):
        src, dst, times, x_src, x_dst = self.data[idx]
        y = self.labels[idx]

        return {
            "src": torch.tensor(src, dtype=torch.long),
            "dst": torch.tensor(dst, dtype=torch.long),
            "t": torch.tensor(times, dtype=torch.float32),
            "x_src": torch.tensor(x_src, dtype=torch.float32),
            "x_dst": torch.tensor(x_dst, dtype=torch.float32),
            "y": torch.tensor(y, dtype=torch.float32)
        }

# %%
from torch.utils.data import DataLoader, random_split
def get_loaders(N, M, batch_size=4, train_split=0.7, val_split=0.15):
    """
    Args:
        N (int): number of nodes (dataset-specific param for CTDGraphDataset).
        M (int): number of samples.
        batch_size (int): batch size for loaders.
        train_split (float): fraction of data to use for training.
        val_split (float): fraction of data to use for validation.
        seed (int): random seed.
        
    Returns:
        train_loader, val_loader, test_loader
    """
    dataset = CTDGraphDataset(N, M)

    # sizes
    train_size = int(train_split * M)
    val_size = int(val_split * M)
    test_size = M - (train_size + val_size)

    # make sure the total matches exactly
    assert train_size + val_size + test_size == M, "Split sizes must sum to dataset size"

    # split
    train_dataset, val_dataset, test_dataset = random_split(
        dataset, [train_size, val_size, test_size], generator=torch.Generator()
    )

    # loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0, path="best_model_sq.pt"):
        self.patience = patience
        self.delta = delta
        self.best_acc = -float("inf")
        self.counter = 0
        self.early_stop = False
        self.path = path  # save checkpoint

    def __call__(self, acc, model):
        if acc > self.best_acc + self.delta:
            self.best_acc = acc
            self.counter = 0
            # save model checkpoint
            torch.save(model.state_dict(), self.path)
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %% [markdown]
# ## Create Dataset

# %% [markdown]
# ## Create Model

# %%
state_dim =32
time_dim = 4
device = 'cuda'
lr = 1e-2/2
epochs = 1600
model = MemoryModel(num_nodes=N+1,input_dim=1,hidden_dim=state_dim,time_dim=time_dim,reg=1e-4,device=device,update_type='mamba').to(device)
path = 'sq_mod.pt'
# Out:
# Static Embeddings: Nil

# %% [markdown]
# ### Train function for Seq. classification

# %%
def train_model(model,train_loader,optimizer,criterion,delta,reg):
    model.train()
    total_loss, total_score, total_samples = 0, [], []
    pred = []
    hidden_state_list = []
    # yt = torch.zeros((len(train_loader),1),device=model.device)
    neighbour = 0

    for batch in train_loader:
        src, dst = batch["src"].to(device), batch["dst"].to(device)
        batch_size = src.shape[0]
        batch_ids = torch.arange(src.shape[0],device=device)
        x_src, x_dst, y = batch["x_src"].to(device), batch["x_dst"].to(device), batch["y"].to(device)
        src_b,dst_b = src+batch_ids[:,None],dst+batch_ids[:,None]
        m1_vec = torch.zeros((batch_size,model.num_nodes,model.hidden_dim),device=model.device)
        ne_vec = torch.zeros((batch_size,model.num_nodes,model.hidden_dim),device=model.device)
        # edge_index = torch.stack([torch.arange(batch_size*model.num_nodes,device=model.device),torch.arange(batch_size*model.num_nodes,device=model.device)])
        for t in range(src.shape[-1]):
            src_t = src_b[0,t]
            dst_t = dst_b[0,t]
            
            if t>0:
                neighbour = src[0,t-1]
            else :
                neighbour = src[0,t]

            src_tau = src[0,:t]
            dst_tau = dst[0,:t]

            L = torch.zeros((dst_t+1,dst_t+1),device=device)
            I = torch.eye(len(L),device=device)
            for u,v in zip(src_tau.tolist(),dst_tau.tolist()):
                L[u,v]=1
                L[v,u]=1

            D = torch.sum(L,dim=1)
            D[D==0]=1
            D = torch.diag(D**(-0.5))
            L_past = I - D@L.clone()@D

            L[src_t,dst_t]=1
            L[dst_t,src_t]=1

            D = torch.sum(L,dim=1)
            D[D==0]=1
            D = torch.diag(D**(-0.5))

            L_present = I - D@L.clone()@D

            active = torch.hstack([neighbour,src_t,dst_t])

            L_sub_present = L_present[active.min():active.max()+1,active.min():active.max()+1] 
            L_sub_past = L_past[active.min():active.max()+1,active.min():active.max()+1]

            if t==0:
                L_sub_past = torch.eye(len(L_sub_past),device=device)

            In = torch.eye(len(L_sub_past )).to(device)
            x_t = torch.zeros((batch_size,len(L_sub_past ),model.input_dim),device=model.device)
            # x_n =  torch.zeros((batch_size,2,model.hidden_dim),device=model.device)

            # Fill Data to Current Node
            if t>0:
                x_t[:,-3] = x_src[:,t-1].unsqueeze(-1)

                
            x_t[:,-2]= x_src[:,t].unsqueeze(-1)
            x_t[:,-1]= x_dst[:,t].unsqueeze(-1)

            
            prev_c_1= m1_vec[:,torch.unique(active)].view((batch_size*(len(L_sub_past )),-1))
            x_batch = x_t.view(batch_size*len(L_sub_past ),-1)
            zt = model.TuneInputSC(x_batch) # input Tuning / Selective Scan
            
            A = model.A_
            At_ = torch.eye(len(A)).to(device) -A.T*delta #torch.matrix_exp(-A.T*delta)
            
            PL_ = model.w[0]*In + model.w[1]*L_sub_present  + model.w[2]*L_sub_present@L_sub_present
            PL_p = model.w[0]*In + model.w[1]*L_sub_past  + model.w[2]*L_sub_past@L_sub_past                  

            PL_inv = torch.linalg.inv(PL_)
            # A_s= 0*In # - PL_inv@PL_p # Uncomment to implement TU-SSM varaiant 
            A_s= In  - PL_inv@PL_p 
            PL_b = torch.block_diag(*PL_inv[None,:,:].repeat(batch_size,1,1))
            A_sb = torch.block_diag(*A_s.unsqueeze(0).repeat(batch_size,1,1))
            updated_c_1=  -A_sb@ prev_c_1 +  prev_c_1 @ At_  +  PL_b @ zt # simple linear approximation of CTT-HiPPO ODE using Forward Euler
            final_state = updated_c_1

            m1_vec[:,torch.unique(active)] = updated_c_1.view(batch_size,len(L_sub_past ),-1)
            ne_vec[:,torch.unique(active)] = final_state.view(batch_size,len(L_sub_past ),-1)

            # edge_index = current_edge_index.clone()

        hidden_state_list.append(ne_vec)
        logits = model.SeqClass(hidden_state_list[-1][:,-1]).view(-1)
        loss = criterion(target = y,input=logits) #+ torch.norm(model.A_hippo-model.A_,p=2)*1e-1
        total_loss += loss #/ batch_size
        # preds = ( logits> 0).float()
        pred += (logits>0).to(int).tolist()
        total_score += logits.tolist()
        total_samples += y.tolist()

        if torch.is_grad_enabled():
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    acc = accuracy_score(pred,total_samples)
    if torch.is_grad_enabled():
        print(f"Epoch | Loss: {total_loss:.4f} | Acc: {acc:.4f}")
        
    else:
        print(f'val/test acc: {acc} ')
    
    return acc

# %% [markdown]
# ## Train Model

# %%
v = []

N = 20           # No. of observation in a seq. 
M=1000           # No. of Seq
batch_size = 400 # Batch Size for loading Seq in model, i.e., we process batch_size number of seq. in a parallel batch.
train_loader,val_laoder,test_loader = get_loaders(N=N,M=M,batch_size=batch_size)

for _ in range(10): # Running for 10 initilizations
    state_dim =32   # Memory Dim
    time_dim = 4    # Time Dim/ Not used 
    device = 'cuda'
    lr = 1e-2
    epochs = 1600
    model = MemoryModel(num_nodes=N+1,input_dim=1,hidden_dim=state_dim,time_dim=time_dim,reg=1e-4,device=device,update_type='mamba').to(device)
    print(f'Init filter coff.: {model.w}')
    path = 'sq_mod_x.pt'
    early_stopper = EarlyStopping(patience=50, delta=1e-3,path=path)
    criterion = nn.BCEWithLogitsLoss()  # for binary classification
    optimizer = optim.Adam(model.parameters(), lr=lr,weight_decay=1e-3)

    delta = 1/(N+1) # Using non-learnable delta 
    for epoch in tqdm(range(epochs),desc='Epochs: '):
        train_model(model,train_loader,optimizer,criterion,delta,0.1)

        with torch.no_grad():
            val_acc = train_model(model,val_laoder,optimizer,criterion,delta,0.1) 
        early_stopper(val_acc, model)
        if early_stopper.early_stop:
            print(f"Early stopping at epoch {epoch+1}")
            break
    
    model.load_state_dict(torch.load(path,weights_only=True))
    print(f'Trained filter coff. :{model.w}')
    with torch.no_grad():
        test_acc = train_model(model,test_loader,optimizer,criterion,delta,0.1)
        v.append(test_acc)
# Out:
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.3743 | Acc: 0.5486
# val/test acc: 0.6533333333333333
# Epoch | Loss: 1.0225 | Acc: 0.7057
# val/test acc: 0.8533333333333334
# Epoch | Loss: 0.7045 | Acc: 0.8514
# val/test acc: 0.9133333333333333
# Epoch | Loss: 0.6751 | Acc: 0.8700
# val/test acc: 0.9333333333333333
# Epoch | Loss: 0.5551 | Acc: 0.8729
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.4930 | Acc: 0.8986
# val/test acc: 0.9066666666666666
# Epoch | Loss: 0.3796 | Acc: 0.9157
# val/test acc: 0.9533333333333334
# Epoch | Loss: 0.2893 | Acc: 0.9386
# val/test acc: 0.96
# Epoch | Loss: 0.2287 | Acc: 0.9443
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1684 | Acc: 0.9571
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2333 | Acc: 0.9529
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0863 | Acc: 0.9829
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1118 | Acc: 0.9829
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1048 | Acc: 0.9814
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0872 | Acc: 0.9857
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0999 | Acc: 0.9814
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0649 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0542 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0456 | Acc: 0.9857
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0369 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0438 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0314 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0291 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0221 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0266 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0319 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0160 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0127 | Acc: 0.9986
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1233 | Acc: 0.9900
# val/test acc: 0.8266666666666667
# Epoch | Loss: 0.7919 | Acc: 0.8914
# val/test acc: 0.96
# Epoch | Loss: 3.0283 | Acc: 0.7414
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1645 | Acc: 0.9671
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.3561 | Acc: 0.9600
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.4686 | Acc: 0.9514
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.4233 | Acc: 0.9443
# val/test acc: 0.96
# Epoch | Loss: 0.4457 | Acc: 0.9429
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.4044 | Acc: 0.9314
# val/test acc: 0.9533333333333334
# Epoch | Loss: 0.4457 | Acc: 0.9100
# val/test acc: 0.94
# Epoch | Loss: 0.4270 | Acc: 0.9171
# val/test acc: 0.98
# Epoch | Loss: 0.2730 | Acc: 0.9500
# val/test acc: 0.98
# Epoch | Loss: 0.1764 | Acc: 0.9657
# val/test acc: 0.98
# Epoch | Loss: 0.1089 | Acc: 0.9814
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0906 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0584 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0682 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0547 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0582 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0487 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0504 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0395 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0451 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0419 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0501 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0370 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0288 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0295 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0252 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0281 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0232 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0277 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0223 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0199 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0187 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0207 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0205 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0226 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0182 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0175 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0229 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0297 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0231 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0259 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0213 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0268 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0128 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0147 | Acc: 0.9986
# val/test acc: 1.0
# Epoch | Loss: 0.0192 | Acc: 0.9971
# val/test acc: 1.0
# Early stopping at epoch 77
# Trained filter coff. :Parameter containing:
# tensor([ 0.1362,  9.6436, 19.4917], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.4343 | Acc: 0.5071
# val/test acc: 0.5666666666666667
# Epoch | Loss: 1.3733 | Acc: 0.5600
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3733 | Acc: 0.5271
# val/test acc: 0.6266666666666667
# Epoch | Loss: 1.2042 | Acc: 0.6700
# val/test acc: 0.8533333333333334
# Epoch | Loss: 0.8443 | Acc: 0.8229
# val/test acc: 0.8933333333333333
# Epoch | Loss: 0.5894 | Acc: 0.8600
# val/test acc: 0.8933333333333333
# Epoch | Loss: 0.5446 | Acc: 0.8829
# val/test acc: 0.9533333333333334
# Epoch | Loss: 0.4400 | Acc: 0.9029
# val/test acc: 0.9266666666666666
# Epoch | Loss: 0.3540 | Acc: 0.9171
# val/test acc: 0.9533333333333334
# Epoch | Loss: 0.3225 | Acc: 0.9457
# val/test acc: 0.96
# Epoch | Loss: 0.2581 | Acc: 0.9529
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1812 | Acc: 0.9486
# val/test acc: 0.98
# Epoch | Loss: 0.1420 | Acc: 0.9643
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1076 | Acc: 0.9757
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1014 | Acc: 0.9786
# val/test acc: 1.0
# Epoch | Loss: 0.0751 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0610 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0599 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0515 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0752 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0648 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0393 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0243 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0293 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0427 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0310 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0304 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0221 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0212 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0197 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0262 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0196 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0368 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0385 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0273 | Acc: 0.9957
# val/test acc: 1.0
# Epoch | Loss: 0.0152 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0302 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0496 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0171 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0280 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0124 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0473 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0693 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0568 | Acc: 0.9900
# val/test acc: 1.0
# Epoch | Loss: 0.0329 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0856 | Acc: 0.9900
# val/test acc: 1.0
# Epoch | Loss: 0.0654 | Acc: 0.9857
# val/test acc: 1.0
# Epoch | Loss: 0.0562 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0502 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0398 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0272 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0429 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0371 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0283 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0307 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0247 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0211 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0185 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0151 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0139 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0180 | Acc: 0.9957
# val/test acc: 1.0
# Epoch | Loss: 0.0335 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0512 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0261 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0114 | Acc: 0.9986
# val/test acc: 1.0
# Early stopping at epoch 65
# Trained filter coff. :Parameter containing:
# tensor([ 0.1557,  9.8222, 19.7151], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.9035 | Acc: 0.4986
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3874 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3784 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3777 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3399 | Acc: 0.5386
# val/test acc: 0.7933333333333333
# Epoch | Loss: 1.1792 | Acc: 0.7829
# val/test acc: 0.76
# Epoch | Loss: 0.8734 | Acc: 0.7957
# val/test acc: 0.8066666666666666
# Epoch | Loss: 0.7495 | Acc: 0.8214
# val/test acc: 0.8466666666666667
# Epoch | Loss: 0.6620 | Acc: 0.8414
# val/test acc: 0.8533333333333334
# Epoch | Loss: 0.6375 | Acc: 0.8414
# val/test acc: 0.9266666666666666
# Epoch | Loss: 0.5640 | Acc: 0.8686
# val/test acc: 0.9533333333333334
# Epoch | Loss: 0.4733 | Acc: 0.8986
# val/test acc: 0.94
# Epoch | Loss: 0.4153 | Acc: 0.9129
# val/test acc: 0.9333333333333333
# Epoch | Loss: 0.3788 | Acc: 0.9271
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.3180 | Acc: 0.9329
# val/test acc: 0.9533333333333334
# Epoch | Loss: 0.2646 | Acc: 0.9443
# val/test acc: 0.96
# Epoch | Loss: 0.2190 | Acc: 0.9471
# val/test acc: 0.98
# Epoch | Loss: 0.1453 | Acc: 0.9671
# val/test acc: 0.98
# Epoch | Loss: 0.1011 | Acc: 0.9771
# val/test acc: 0.94
# Epoch | Loss: 0.3166 | Acc: 0.9400
# val/test acc: 0.98
# Epoch | Loss: 0.1572 | Acc: 0.9671
# val/test acc: 0.96
# Epoch | Loss: 0.2156 | Acc: 0.9614
# val/test acc: 0.96
# Epoch | Loss: 0.1785 | Acc: 0.9643
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1468 | Acc: 0.9629
# val/test acc: 0.96
# Epoch | Loss: 0.1696 | Acc: 0.9614
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1639 | Acc: 0.9600
# val/test acc: 0.96
# Epoch | Loss: 0.1530 | Acc: 0.9671
# val/test acc: 0.98
# Epoch | Loss: 0.1208 | Acc: 0.9800
# val/test acc: 0.98
# Epoch | Loss: 0.0950 | Acc: 0.9814
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0733 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0678 | Acc: 0.9843
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0663 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0804 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0803 | Acc: 0.9814
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1046 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1365 | Acc: 0.9814
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0596 | Acc: 0.9786
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1456 | Acc: 0.9786
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0673 | Acc: 0.9857
# val/test acc: 0.98
# Epoch | Loss: 0.1202 | Acc: 0.9714
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0918 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0940 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0732 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0556 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0709 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0562 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0605 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0535 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0340 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0466 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0369 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0598 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0306 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0406 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0537 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0388 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0470 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0669 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0587 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0546 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0370 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0478 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0410 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0401 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0362 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0333 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0282 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0412 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0415 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0364 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0239 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0265 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0287 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0310 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0254 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0300 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0443 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0285 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0219 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0228 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0270 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0355 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0160 | Acc: 0.9986
# val/test acc: 1.0
# Epoch | Loss: 0.0237 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0247 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0200 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0228 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0137 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0136 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0197 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0297 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0617 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0343 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0176 | Acc: 0.9957
# val/test acc: 1.0
# Epoch | Loss: 0.0281 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0764 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0483 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0331 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0323 | Acc: 0.9957
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0324 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0372 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0268 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0373 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0259 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0173 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0167 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0131 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0162 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0216 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0124 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0121 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0121 | Acc: 0.9986
# val/test acc: 1.0
# Epoch | Loss: 0.0144 | Acc: 0.9971
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0055 | Acc: 1.0000
# val/test acc: 1.0
# Epoch | Loss: 0.0305 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1188 | Acc: 0.9843
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.2111 | Acc: 0.9843
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0928 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0472 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1109 | Acc: 0.9857
# val/test acc: 0.6933333333333334
# Epoch | Loss: 2.9150 | Acc: 0.5557
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2960 | Acc: 0.9600
# val/test acc: 0.96
# Epoch | Loss: 0.5555 | Acc: 0.8986
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.5554 | Acc: 0.9086
# val/test acc: 0.92
# Epoch | Loss: 0.7853 | Acc: 0.8657
# val/test acc: 0.92
# Early stopping at epoch 125
# Trained filter coff. :Parameter containing:
# tensor([ 0.1718,  9.4585, 18.8749], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.6420 | Acc: 0.5229
# val/test acc: 0.46
# Epoch | Loss: 1.3893 | Acc: 0.5100
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.4016 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3218 | Acc: 0.5257
# val/test acc: 0.7066666666666667
# Epoch | Loss: 1.0187 | Acc: 0.7157
# val/test acc: 0.8866666666666667
# Epoch | Loss: 0.7988 | Acc: 0.8271
# val/test acc: 0.9066666666666666
# Epoch | Loss: 0.7608 | Acc: 0.8700
# val/test acc: 0.9266666666666666
# Epoch | Loss: 0.5411 | Acc: 0.8800
# val/test acc: 0.86
# Epoch | Loss: 0.4996 | Acc: 0.8857
# val/test acc: 0.9333333333333333
# Epoch | Loss: 0.4353 | Acc: 0.9071
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.3585 | Acc: 0.9314
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2499 | Acc: 0.9443
# val/test acc: 0.9533333333333334
# Epoch | Loss: 0.2420 | Acc: 0.9457
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.2392 | Acc: 0.9529
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.2021 | Acc: 0.9686
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1873 | Acc: 0.9657
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1356 | Acc: 0.9757
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1003 | Acc: 0.9871
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1121 | Acc: 0.9686
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1397 | Acc: 0.9743
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1263 | Acc: 0.9714
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0851 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0915 | Acc: 0.9786
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1031 | Acc: 0.9743
# val/test acc: 1.0
# Epoch | Loss: 0.0898 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0562 | Acc: 0.9871
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0709 | Acc: 0.9843
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0883 | Acc: 0.9843
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0490 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0655 | Acc: 0.9857
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0500 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0485 | Acc: 0.9886
# val/test acc: 1.0
# Epoch | Loss: 0.0493 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0540 | Acc: 0.9900
# val/test acc: 1.0
# Epoch | Loss: 0.0574 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0357 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0379 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0398 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0359 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0299 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0280 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0451 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0480 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.1498 | Acc: 0.9757
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0730 | Acc: 0.9886
# val/test acc: 1.0
# Epoch | Loss: 0.0547 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0656 | Acc: 0.9843
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0467 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0396 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0437 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0402 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0349 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0363 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0479 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0316 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0271 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0356 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0338 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0296 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0244 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0225 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0269 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0299 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0580 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0636 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0380 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0229 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0237 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0223 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0216 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0312 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0289 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0252 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0167 | Acc: 0.9957
# val/test acc: 0.9866666666666667
# Early stopping at epoch 74
# Trained filter coff. :Parameter containing:
# tensor([ 0.2216,  9.8932, 19.7119], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.4651 | Acc: 0.5057
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.4004 | Acc: 0.5171
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.4220 | Acc: 0.4743
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.3933 | Acc: 0.4743
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.3922 | Acc: 0.4743
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.3896 | Acc: 0.4743
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3843 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3825 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3673 | Acc: 0.5257
# val/test acc: 0.6933333333333334
# Epoch | Loss: 1.3023 | Acc: 0.6843
# val/test acc: 0.8466666666666667
# Epoch | Loss: 1.0590 | Acc: 0.8129
# val/test acc: 0.8066666666666666
# Epoch | Loss: 0.8675 | Acc: 0.7943
# val/test acc: 0.8133333333333334
# Epoch | Loss: 0.7586 | Acc: 0.8071
# val/test acc: 0.8466666666666667
# Epoch | Loss: 0.6690 | Acc: 0.8371
# val/test acc: 0.8866666666666667
# Epoch | Loss: 0.6083 | Acc: 0.8643
# val/test acc: 0.92
# Epoch | Loss: 0.5845 | Acc: 0.8743
# val/test acc: 0.9066666666666666
# Epoch | Loss: 0.5174 | Acc: 0.8814
# val/test acc: 0.9333333333333333
# Epoch | Loss: 0.4738 | Acc: 0.9043
# val/test acc: 0.94
# Epoch | Loss: 0.4391 | Acc: 0.9143
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.3513 | Acc: 0.9229
# val/test acc: 0.96
# Epoch | Loss: 0.2701 | Acc: 0.9443
# val/test acc: 0.96
# Epoch | Loss: 0.1935 | Acc: 0.9529
# val/test acc: 0.96
# Epoch | Loss: 0.1380 | Acc: 0.9729
# val/test acc: 0.98
# Epoch | Loss: 0.2735 | Acc: 0.9643
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2257 | Acc: 0.9614
# val/test acc: 0.98
# Epoch | Loss: 0.1155 | Acc: 0.9743
# val/test acc: 0.96
# Epoch | Loss: 0.2220 | Acc: 0.9571
# val/test acc: 0.96
# Epoch | Loss: 0.1721 | Acc: 0.9700
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1263 | Acc: 0.9700
# val/test acc: 0.98
# Epoch | Loss: 0.1056 | Acc: 0.9786
# val/test acc: 0.98
# Epoch | Loss: 0.0843 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0845 | Acc: 0.9800
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0695 | Acc: 0.9857
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0852 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0612 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0608 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0442 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0498 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0349 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0480 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0318 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0282 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0943 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0388 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0905 | Acc: 0.9857
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0357 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0429 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0345 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0345 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0418 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0275 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0311 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0327 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0262 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0245 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0241 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0223 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0233 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0550 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1917 | Acc: 0.9843
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.2805 | Acc: 0.9686
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2174 | Acc: 0.9700
# val/test acc: 0.9133333333333333
# Epoch | Loss: 0.2190 | Acc: 0.9600
# val/test acc: 0.98
# Epoch | Loss: 0.1309 | Acc: 0.9757
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1295 | Acc: 0.9743
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1703 | Acc: 0.9686
# val/test acc: 0.98
# Epoch | Loss: 0.1367 | Acc: 0.9714
# val/test acc: 0.98
# Epoch | Loss: 0.1486 | Acc: 0.9743
# val/test acc: 0.98
# Epoch | Loss: 0.1038 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1071 | Acc: 0.9743
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0960 | Acc: 0.9771
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0920 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0926 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0656 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0591 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0457 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0429 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0408 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0405 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0386 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0341 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0399 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0231 | Acc: 0.9957
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0373 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0237 | Acc: 0.9986
# val/test acc: 1.0
# Epoch | Loss: 0.0400 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0196 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0195 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0216 | Acc: 0.9943
# val/test acc: 1.0
# Early stopping at epoch 89
# Trained filter coff. :Parameter containing:
# tensor([ 0.2259,  9.6316, 19.4129], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.5473 | Acc: 0.4743
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.3612 | Acc: 0.4900
# val/test acc: 0.72
# Epoch | Loss: 1.1136 | Acc: 0.7714
# val/test acc: 0.8
# Epoch | Loss: 0.8530 | Acc: 0.7929
# val/test acc: 0.9
# Epoch | Loss: 0.6441 | Acc: 0.8457
# val/test acc: 0.86
# Epoch | Loss: 0.6620 | Acc: 0.8486
# val/test acc: 0.8666666666666667
# Epoch | Loss: 0.5979 | Acc: 0.8657
# val/test acc: 0.9
# Epoch | Loss: 0.4694 | Acc: 0.9029
# val/test acc: 0.96
# Epoch | Loss: 0.3801 | Acc: 0.9286
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.3031 | Acc: 0.9357
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2494 | Acc: 0.9414
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1892 | Acc: 0.9514
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1772 | Acc: 0.9586
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1680 | Acc: 0.9686
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1796 | Acc: 0.9729
# val/test acc: 0.96
# Epoch | Loss: 0.1973 | Acc: 0.9629
# val/test acc: 0.98
# Epoch | Loss: 0.1665 | Acc: 0.9714
# val/test acc: 0.98
# Epoch | Loss: 0.1092 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0919 | Acc: 0.9814
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2473 | Acc: 0.9586
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1269 | Acc: 0.9786
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0885 | Acc: 0.9814
# val/test acc: 0.98
# Epoch | Loss: 0.2904 | Acc: 0.9700
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.3772 | Acc: 0.9514
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.6129 | Acc: 0.9371
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.3174 | Acc: 0.9500
# val/test acc: 0.88
# Epoch | Loss: 0.5562 | Acc: 0.8886
# val/test acc: 0.9466666666666667
# Epoch | Loss: 0.3282 | Acc: 0.9314
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2105 | Acc: 0.9614
# val/test acc: 0.98
# Epoch | Loss: 0.1975 | Acc: 0.9586
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1911 | Acc: 0.9629
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1735 | Acc: 0.9643
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1629 | Acc: 0.9700
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1497 | Acc: 0.9714
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1307 | Acc: 0.9757
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1088 | Acc: 0.9800
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0860 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0743 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0625 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0515 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0457 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0410 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0375 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0347 | Acc: 0.9957
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0342 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0356 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0308 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0277 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0299 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0726 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0760 | Acc: 0.9857
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0580 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0374 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0749 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1043 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0445 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0266 | Acc: 0.9957
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0445 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0375 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0380 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0310 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0313 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0333 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0324 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0358 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0248 | Acc: 0.9957
# val/test acc: 1.0
# Epoch | Loss: 0.0286 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0317 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0574 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0478 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0282 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0592 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0480 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0630 | Acc: 0.9843
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0320 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0412 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0368 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0325 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0301 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0318 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0310 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0209 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0262 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0303 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0280 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0254 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0195 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0259 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0188 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0126 | Acc: 0.9986
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0258 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0467 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1230 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0226 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0327 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0758 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0466 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0366 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0327 | Acc: 0.9929
# val/test acc: 1.0
# Early stopping at epoch 99
# Trained filter coff. :Parameter containing:
# tensor([ 0.2050,  9.7086, 19.4711], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.4310 | Acc: 0.4543
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3898 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3853 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3750 | Acc: 0.5257
# val/test acc: 0.5533333333333333
# Epoch | Loss: 1.3171 | Acc: 0.5686
# val/test acc: 0.7333333333333333
# Epoch | Loss: 1.0802 | Acc: 0.7300
# val/test acc: 0.8066666666666666
# Epoch | Loss: 0.7947 | Acc: 0.8057
# val/test acc: 0.82
# Epoch | Loss: 0.8163 | Acc: 0.8357
# val/test acc: 0.9066666666666666
# Epoch | Loss: 0.5831 | Acc: 0.8900
# val/test acc: 0.9066666666666666
# Epoch | Loss: 0.4309 | Acc: 0.8871
# val/test acc: 0.9333333333333333
# Epoch | Loss: 0.4440 | Acc: 0.9157
# val/test acc: 0.92
# Epoch | Loss: 0.3246 | Acc: 0.9371
# val/test acc: 0.9266666666666666
# Epoch | Loss: 0.2962 | Acc: 0.9386
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2023 | Acc: 0.9500
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2535 | Acc: 0.9614
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1653 | Acc: 0.9529
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1610 | Acc: 0.9686
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1371 | Acc: 0.9743
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1155 | Acc: 0.9800
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1078 | Acc: 0.9800
# val/test acc: 0.98
# Epoch | Loss: 0.1233 | Acc: 0.9771
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0780 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0782 | Acc: 0.9857
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1572 | Acc: 0.9771
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1252 | Acc: 0.9729
# val/test acc: 0.96
# Epoch | Loss: 0.1655 | Acc: 0.9686
# val/test acc: 0.98
# Epoch | Loss: 0.0989 | Acc: 0.9786
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1192 | Acc: 0.9786
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0926 | Acc: 0.9757
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0823 | Acc: 0.9786
# val/test acc: 1.0
# Epoch | Loss: 0.0807 | Acc: 0.9829
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0707 | Acc: 0.9829
# val/test acc: 0.98
# Epoch | Loss: 0.0582 | Acc: 0.9857
# val/test acc: 1.0
# Epoch | Loss: 0.0774 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0523 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0385 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0388 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0344 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0396 | Acc: 0.9914
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2693 | Acc: 0.9700
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0945 | Acc: 0.9814
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0652 | Acc: 0.9843
# val/test acc: 0.98
# Epoch | Loss: 0.1290 | Acc: 0.9743
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0918 | Acc: 0.9800
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0806 | Acc: 0.9814
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0715 | Acc: 0.9786
# val/test acc: 1.0
# Epoch | Loss: 0.0822 | Acc: 0.9829
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0641 | Acc: 0.9814
# val/test acc: 0.98
# Epoch | Loss: 0.0565 | Acc: 0.9829
# val/test acc: 1.0
# Epoch | Loss: 0.0597 | Acc: 0.9871
# val/test acc: 0.98
# Epoch | Loss: 0.0541 | Acc: 0.9829
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0413 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0433 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0433 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0331 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0328 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0351 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0509 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0538 | Acc: 0.9900
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1000 | Acc: 0.9814
# val/test acc: 1.0
# Epoch | Loss: 0.0890 | Acc: 0.9843
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0512 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0655 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0570 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0451 | Acc: 0.9900
# val/test acc: 1.0
# Epoch | Loss: 0.0760 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0998 | Acc: 0.9829
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0488 | Acc: 0.9871
# val/test acc: 1.0
# Epoch | Loss: 0.0861 | Acc: 0.9843
# val/test acc: 1.0
# Epoch | Loss: 0.0665 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0686 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0403 | Acc: 0.9900
# val/test acc: 1.0
# Epoch | Loss: 0.0719 | Acc: 0.9857
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0363 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0562 | Acc: 0.9871
# val/test acc: 1.0
# Epoch | Loss: 0.0725 | Acc: 0.9900
# val/test acc: 1.0
# Epoch | Loss: 0.0575 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0733 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0680 | Acc: 0.9857
# val/test acc: 1.0
# Epoch | Loss: 0.0496 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Early stopping at epoch 80
# Trained filter coff. :Parameter containing:
# tensor([ 0.1469,  9.6865, 19.4407], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.4185 | Acc: 0.4986
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3848 | Acc: 0.5257
# val/test acc: 0.54
# Epoch | Loss: 1.3505 | Acc: 0.5900
# val/test acc: 0.7733333333333333
# Epoch | Loss: 1.1998 | Acc: 0.7286
# val/test acc: 0.8266666666666667
# Epoch | Loss: 0.8675 | Acc: 0.7857
# val/test acc: 0.84
# Epoch | Loss: 0.7247 | Acc: 0.8357
# val/test acc: 0.88
# Epoch | Loss: 0.6186 | Acc: 0.8657
# val/test acc: 0.9133333333333333
# Epoch | Loss: 0.4663 | Acc: 0.9086
# val/test acc: 0.9266666666666666
# Epoch | Loss: 0.3567 | Acc: 0.9214
# val/test acc: 0.94
# Epoch | Loss: 0.3067 | Acc: 0.9529
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1908 | Acc: 0.9586
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1669 | Acc: 0.9614
# val/test acc: 0.98
# Epoch | Loss: 0.2426 | Acc: 0.9586
# val/test acc: 0.98
# Epoch | Loss: 0.1659 | Acc: 0.9743
# val/test acc: 0.9333333333333333
# Epoch | Loss: 0.2178 | Acc: 0.9586
# val/test acc: 1.0
# Epoch | Loss: 0.1157 | Acc: 0.9829
# val/test acc: 0.94
# Epoch | Loss: 0.1786 | Acc: 0.9600
# val/test acc: 0.98
# Epoch | Loss: 0.1592 | Acc: 0.9714
# val/test acc: 1.0
# Epoch | Loss: 0.1171 | Acc: 0.9771
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1028 | Acc: 0.9757
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1239 | Acc: 0.9729
# val/test acc: 1.0
# Epoch | Loss: 0.0860 | Acc: 0.9814
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0936 | Acc: 0.9771
# val/test acc: 1.0
# Epoch | Loss: 0.0868 | Acc: 0.9800
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0999 | Acc: 0.9743
# val/test acc: 0.98
# Epoch | Loss: 0.1004 | Acc: 0.9771
# val/test acc: 1.0
# Epoch | Loss: 0.0632 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0636 | Acc: 0.9900
# val/test acc: 1.0
# Epoch | Loss: 0.0515 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0343 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0345 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0438 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.1436 | Acc: 0.9843
# val/test acc: 0.98
# Epoch | Loss: 0.0906 | Acc: 0.9871
# val/test acc: 1.0
# Epoch | Loss: 0.0749 | Acc: 0.9857
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0379 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0367 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0480 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0401 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0400 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0342 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0412 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0391 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0497 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0367 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0319 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0358 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0626 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.1551 | Acc: 0.9871
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2611 | Acc: 0.9686
# val/test acc: 0.98
# Epoch | Loss: 0.2086 | Acc: 0.9700
# val/test acc: 0.98
# Epoch | Loss: 0.1601 | Acc: 0.9786
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0987 | Acc: 0.9757
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1147 | Acc: 0.9743
# val/test acc: 1.0
# Epoch | Loss: 0.1037 | Acc: 0.9800
# val/test acc: 0.98
# Epoch | Loss: 0.0875 | Acc: 0.9771
# val/test acc: 0.98
# Epoch | Loss: 0.0679 | Acc: 0.9843
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0724 | Acc: 0.9814
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0641 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0593 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0541 | Acc: 0.9843
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0450 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0371 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0337 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0259 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Early stopping at epoch 65
# Trained filter coff. :Parameter containing:
# tensor([ 0.1722,  9.8469, 19.7295], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 2.7123 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.4046 | Acc: 0.5100
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.4148 | Acc: 0.4743
# val/test acc: 0.5533333333333333
# Epoch | Loss: 1.3789 | Acc: 0.5357
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3867 | Acc: 0.5243
# val/test acc: 0.56
# Epoch | Loss: 1.3153 | Acc: 0.5771
# val/test acc: 0.78
# Epoch | Loss: 1.0832 | Acc: 0.7514
# val/test acc: 0.8133333333333334
# Epoch | Loss: 0.8265 | Acc: 0.8014
# val/test acc: 0.84
# Epoch | Loss: 0.6977 | Acc: 0.8357
# val/test acc: 0.8866666666666667
# Epoch | Loss: 0.6577 | Acc: 0.8557
# val/test acc: 0.8933333333333333
# Epoch | Loss: 0.5631 | Acc: 0.8714
# val/test acc: 0.9066666666666666
# Epoch | Loss: 0.4627 | Acc: 0.8871
# val/test acc: 0.96
# Epoch | Loss: 0.3290 | Acc: 0.9414
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1946 | Acc: 0.9643
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2073 | Acc: 0.9614
# val/test acc: 0.98
# Epoch | Loss: 0.2412 | Acc: 0.9643
# val/test acc: 0.96
# Epoch | Loss: 0.2358 | Acc: 0.9557
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2162 | Acc: 0.9629
# val/test acc: 0.98
# Epoch | Loss: 0.1783 | Acc: 0.9671
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1274 | Acc: 0.9743
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1240 | Acc: 0.9800
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1325 | Acc: 0.9771
# val/test acc: 0.98
# Epoch | Loss: 0.1170 | Acc: 0.9800
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.0998 | Acc: 0.9786
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0962 | Acc: 0.9757
# val/test acc: 0.98
# Epoch | Loss: 0.0809 | Acc: 0.9800
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0888 | Acc: 0.9814
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0720 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0532 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0505 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0543 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0594 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0511 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0489 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0558 | Acc: 0.9871
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0592 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0458 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0904 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0459 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0639 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0884 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0649 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0707 | Acc: 0.9843
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0536 | Acc: 0.9843
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0651 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0399 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0427 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0395 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0292 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0328 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0225 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0273 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0228 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0370 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0208 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0224 | Acc: 0.9971
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0322 | Acc: 0.9943
# val/test acc: 1.0
# Epoch | Loss: 0.0323 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0162 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0223 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0170 | Acc: 0.9971
# val/test acc: 1.0
# Epoch | Loss: 0.0280 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0576 | Acc: 0.9929
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1321 | Acc: 0.9843
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2102 | Acc: 0.9786
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.9011 | Acc: 0.8271
# val/test acc: 0.9866666666666667
# Epoch | Loss: 4.8621 | Acc: 0.8129
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.5314 | Acc: 0.9686
# val/test acc: 0.9066666666666666
# Epoch | Loss: 1.8429 | Acc: 0.9071
# val/test acc: 0.9
# Epoch | Loss: 1.0716 | Acc: 0.9000
# val/test acc: 0.9
# Epoch | Loss: 0.5811 | Acc: 0.8786
# val/test acc: 0.8666666666666667
# Epoch | Loss: 0.8902 | Acc: 0.7843
# val/test acc: 0.8266666666666667
# Epoch | Loss: 0.8902 | Acc: 0.7843
# val/test acc: 0.9066666666666666
# Epoch | Loss: 0.8453 | Acc: 0.8529
# val/test acc: 0.8933333333333333
# Epoch | Loss: 0.9108 | Acc: 0.8386
# val/test acc: 0.8133333333333334
# Epoch | Loss: 0.9271 | Acc: 0.8000
# val/test acc: 0.82
# Epoch | Loss: 0.8747 | Acc: 0.8143
# val/test acc: 0.8733333333333333
# Epoch | Loss: 0.7764 | Acc: 0.8600
# val/test acc: 0.8866666666666667
# Epoch | Loss: 0.6799 | Acc: 0.8800
# val/test acc: 0.8866666666666667
# Epoch | Loss: 0.5982 | Acc: 0.8929
# val/test acc: 0.8933333333333333
# Epoch | Loss: 0.5422 | Acc: 0.9043
# val/test acc: 0.9
# Epoch | Loss: 0.5193 | Acc: 0.9057
# val/test acc: 0.9133333333333333
# Epoch | Loss: 0.4904 | Acc: 0.9086
# val/test acc: 0.92
# Epoch | Loss: 0.4490 | Acc: 0.9086
# val/test acc: 0.94
# Epoch | Loss: 0.4063 | Acc: 0.9114
# val/test acc: 0.96
# Epoch | Loss: 0.3454 | Acc: 0.9243
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2874 | Acc: 0.9471
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.2545 | Acc: 0.9614
# val/test acc: 0.96
# Epoch | Loss: 0.2187 | Acc: 0.9571
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1812 | Acc: 0.9643
# val/test acc: 0.98
# Epoch | Loss: 0.1561 | Acc: 0.9686
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1375 | Acc: 0.9743
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1323 | Acc: 0.9743
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1075 | Acc: 0.9757
# val/test acc: 0.98
# Epoch | Loss: 0.1041 | Acc: 0.9786
# val/test acc: 0.98
# Epoch | Loss: 0.0937 | Acc: 0.9829
# val/test acc: 0.98
# Early stopping at epoch 96
# Trained filter coff. :Parameter containing:
# tensor([ 0.2221,  9.7333, 19.2854], device='cuda:0', requires_grad=True)
# val/test acc: 0.98
# Static Embeddings: Nil
# Init filter coff.: Parameter containing:
# tensor([ 0.2500, 10.0000, 20.0000], device='cuda:0', requires_grad=True)
# Epochs:   0%|          | 0/1600 [00:00<?, ?it/s]
# Epoch | Loss: 1.4531 | Acc: 0.4814
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.4618 | Acc: 0.4743
# val/test acc: 0.4666666666666667
# Epoch | Loss: 1.3974 | Acc: 0.4743
# val/test acc: 0.5266666666666666
# Epoch | Loss: 1.3895 | Acc: 0.5071
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3813 | Acc: 0.5257
# val/test acc: 0.5333333333333333
# Epoch | Loss: 1.3559 | Acc: 0.5400
# val/test acc: 0.6266666666666667
# Epoch | Loss: 1.2684 | Acc: 0.6371
# val/test acc: 0.76
# Epoch | Loss: 1.0304 | Acc: 0.7457
# val/test acc: 0.8533333333333334
# Epoch | Loss: 0.8190 | Acc: 0.8114
# val/test acc: 0.86
# Epoch | Loss: 0.7278 | Acc: 0.8171
# val/test acc: 0.88
# Epoch | Loss: 0.6951 | Acc: 0.8471
# val/test acc: 0.9266666666666666
# Epoch | Loss: 0.5959 | Acc: 0.8714
# val/test acc: 0.9133333333333333
# Epoch | Loss: 0.5452 | Acc: 0.8843
# val/test acc: 0.9266666666666666
# Epoch | Loss: 0.4774 | Acc: 0.9000
# val/test acc: 0.9333333333333333
# Epoch | Loss: 0.3482 | Acc: 0.9200
# val/test acc: 0.96
# Epoch | Loss: 0.3579 | Acc: 0.9286
# val/test acc: 0.94
# Epoch | Loss: 0.3122 | Acc: 0.9271
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.2485 | Acc: 0.9400
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1888 | Acc: 0.9500
# val/test acc: 0.9666666666666667
# Epoch | Loss: 0.1933 | Acc: 0.9529
# val/test acc: 0.98
# Epoch | Loss: 0.1735 | Acc: 0.9657
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1490 | Acc: 0.9686
# val/test acc: 0.98
# Epoch | Loss: 0.1171 | Acc: 0.9743
# val/test acc: 0.98
# Epoch | Loss: 0.0855 | Acc: 0.9786
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0896 | Acc: 0.9814
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1334 | Acc: 0.9757
# val/test acc: 0.96
# Epoch | Loss: 0.1857 | Acc: 0.9671
# val/test acc: 0.9733333333333334
# Epoch | Loss: 0.1071 | Acc: 0.9771
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0801 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0847 | Acc: 0.9829
# val/test acc: 0.98
# Epoch | Loss: 0.0748 | Acc: 0.9886
# val/test acc: 0.98
# Epoch | Loss: 0.0633 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0621 | Acc: 0.9829
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0621 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0601 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0475 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0549 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0580 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0623 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0470 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0421 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0408 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0358 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0383 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0328 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0381 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0424 | Acc: 0.9900
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0369 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0294 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0480 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0689 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0549 | Acc: 0.9857
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0422 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0476 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0423 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0349 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0389 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0280 | Acc: 0.9943
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0371 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0349 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0357 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0411 | Acc: 0.9886
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0515 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0251 | Acc: 0.9957
# val/test acc: 1.0
# Epoch | Loss: 0.0360 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0465 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0335 | Acc: 0.9914
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0307 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0360 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0326 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0322 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0299 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0271 | Acc: 0.9943
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0449 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0470 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0477 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0375 | Acc: 0.9914
# val/test acc: 1.0
# Epoch | Loss: 0.0470 | Acc: 0.9871
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0570 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0415 | Acc: 0.9929
# val/test acc: 1.0
# Epoch | Loss: 0.0399 | Acc: 0.9886
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0326 | Acc: 0.9929
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0380 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0280 | Acc: 0.9957
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0295 | Acc: 0.9914
# val/test acc: 0.9866666666666667
# Epoch | Loss: 0.0258 | Acc: 0.9929
# val/test acc: 0.9933333333333333
# Epoch | Loss: 0.0300 | Acc: 0.9900
# val/test acc: 0.9933333333333333
# Early stopping at epoch 87
# Trained filter coff. :Parameter containing:
# tensor([ 0.1626,  9.6068, 19.3942], device='cuda:0', requires_grad=True)
# val/test acc: 0.9866666666666667

# %%
print(f"Mean: {np.mean(v)}, std:{np.std(v)}")
# Out:
# Mean: 0.986, std:0.002000000000000013
